# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...

# %%
Image("3.jpeg")

# %%
output = reader.readtext('3.jpeg')

# %%
output
# Out:
# [([[0, 0], [53, 0], [53, 17], [0, 17]], 'LAl', 0.01357295922935009),
#  ([[59, 0], [169, 0], [169, 13], [59, 13]], 'a3', 0.00016719962877687067),
#  ([[1140, 0], [1196, 0], [1196, 28], [1140, 28]], '667', 0.3661707043647766),
#  ([[128, 54], [194, 54], [194, 86], [128, 86]], '13.7', 0.3702016770839691),
#  ([[217, 50], [536, 50], [536, 100], [217, 100]],
#   'BASIC THEOREMS OF',
#   0.30872637033462524),
#  ([[535, 67], [815, 67], [815, 111], [535, 111]],
#   'BOOLEAN ALGEBRA',
#   0.6086107492446899),
#  ([[181, 104], [1215, 104], [1215, 169], [181, 169]],
#   'Basic postulates of boolean algebra are used to define basic theorems ofboolean algebra',
#   0.0900692567229271),
#  ([[121, 140], [339, 140], [339, 177], [121, 177]],
#   'that provide all',
#   0.4574708342552185),
#  ([[346, 148], [392, 148], [392, 176], [346, 176]], 'the', 0.8830742835998535),
#  ([[399, 149], [649, 149], [649, 192], [399, 192]],
#   'tools necessary for',
#   0.3160398006439209),
# ...

# %%
len(output)
# Out:
# 30

# %%
total = ""
for i in output:
    total += " "+ i[1] 
total
# Out:
# ' LAl a3 667 13.7 BASIC THEOREMS OF BOOLEAN ALGEBRA Basic postulates of boolean algebra are used to define basic theorems ofboolean algebra that provide all the tools necessary for simple in appearance, these manipulating boolean expressions. Although theorems may be used to construct the boolean algebra. 13.7.1 Properties of O and a)0+X=X OR (gate representation of(a)) (b)1+X=1 OR (gate representation of(b)) X 0 (c) 0.X=0 (gate representation of(c)) AND (d)l.X= X (gate representation of(a)) AND X'
