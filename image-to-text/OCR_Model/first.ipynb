# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...

# %%
Image("4.jpeg")

# %%
output = reader.readtext('1.jpeg')

# %%
output
# Out:
# [([[331, 302], [890, 302], [890, 355], [331, 355]],
#   'THE RUDEST BOOK EVER',
#   0.27453160285949707),
#  ([[208, 434], [340, 434], [340, 466], [208, 466]],
#   'Shwetabh',
#   0.9962028861045837),
#  ([[339, 426], [640, 426], [640, 478], [339, 478]],
#   'Gangwar is a novelist,',
#   0.4313850998878479),
#  ([[730, 419], [1023, 419], [1023, 474], [730, 474]],
#   'speaker, professional',
#   0.5745632648468018),
#  ([[198, 472], [411, 472], [411, 517], [198, 517]],
#   'problem-solver,',
#   0.5173887610435486),
#  ([[426, 478], [482, 478], [482, 508], [426, 508]], 'and', 0.944305419921875),
#  ([[498, 478], [548, 478], [548, 508], [498, 508]], 'has', 0.9909592270851135),
#  ([[562, 484], [626, 484], [626, 508], [562, 508]],
#   'over',
#   0.9568246603012085),
#  ([[640, 482], [696, 482], [696, 506], [640, 506]], 'tWO', 0.6679807305335999),
#  ([[712, 473], [818, 473], [818, 509], [712, 509]],
#   'million',
#   0.9740763306617737),
# ...

# %%
len(output)
# Out:
# 27

# %%
total = ""
for i in output:
    total += " "+ i[1] 
total
# Out:
# ' THE RUDEST BOOK EVER Shwetabh Gangwar is a novelist, speaker, professional problem-solver, and has over tWO million followers on YouTube. He dedicatedly solves problems sent tO him on his Instagram, and makes videos on as many as he can. He defnes it as the purpose ofhis life and what truly him meaning public peoples brings'
